# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('../data/incheon_bus_station.csv',encoding='cp949')

# %%
df
# Out:
#               정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  \
# 0       (구)국제여객터미널     35051.0         99       1671        21      1671
# 1       (구)국제여객터미널     35052.0       2374         44      2312        44
# 2        (주)경동세라믹스     89146.0        315         39       312        39
# 3         (주)경인양행앞     42096.0        973        814       957       814
# 4         (주)경인양행앞     42097.0       1452       3459      1424      3459
# ...            ...         ...        ...        ...       ...       ...
# 6415  힐스테이트학익104동앞     37670.0       1781       4482      1749      4482
# 6416        힐캐슬프라자     39329.0      10669      15269     10502     15269
# 6417        힐캐슬프라자     39331.0      16539       8669     16195      8669
# 6418          힘찬병원     40891.0       5178       6917      5118      6917
# 6419          힘찬병원     40892.0       4027       3057      3975      3057
#
#       승차건수(현금)  일평균 승하차건수
# 0           78         59
# 1           62         80
# ...

# %%
df.describe()
# Out:
#          정류소아이디(ID)      승차건수(총합계)      하차건수(총합계)       승차건수(카드)  \
# count   6419.000000    6420.000000    6420.000000    6420.000000
# mean   46765.374202    3539.242991    3327.254517    3485.515109
# std    17185.357154    8504.342678    7560.981341    8415.938134
# min    11002.000000       0.000000       0.000000       0.000000
# 25%    38341.500000      53.000000      62.000000      47.000000
# 50%    40828.000000     719.000000     842.500000     702.000000
# 75%    43503.500000    3647.500000    3573.250000    3579.500000
# max    92065.000000  177804.000000  164453.000000  175729.000000
#
#             하차건수(카드)     승차건수(현금)     일평균 승하차건수
# count    6420.000000  6420.000000   6420.000000
# mean     3327.254517    53.727882    228.406698
# std      7560.981341   114.938878    506.400423
# min         0.000000     0.000000      0.000000
# 25%        62.000000     1.000000      6.000000
# 50%       842.500000    12.000000     69.000000
# ...

# %%
# 일평균 승하차건수가 많은 곳은?

# %%
df['일평균 승하차건수'] == df['일평균 승하차건수'].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6415    False
# 6416    False
# 6417    False
# 6418    False
# 6419    False
# Name: 일평균 승하차건수, Length: 6420, dtype: bool

# %%
df.loc[df['일평균 승하차건수'] == df['일평균 승하차건수'].max() , ]
# Out:
#               정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  \
# 1872  롯데백화점(인천터미널)     37513.0     177804     164453    175729    164453
#
#       승차건수(현금)  일평균 승하차건수
# 1872      2075      11408

# %%
df.loc[df['승차건수(총합계)'] == df['승차건수(총합계)'].max() , ]
# Out:
#               정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  \
# 1872  롯데백화점(인천터미널)     37513.0     177804     164453    175729    164453
#
#       승차건수(현금)  일평균 승하차건수
# 1872      2075      11408

# %%
df.loc[df['하차건수(총합계)'] == df['하차건수(총합계)'].max() , ]
# Out:
#               정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  \
# 1872  롯데백화점(인천터미널)     37513.0     177804     164453    175729    164453
#
#       승차건수(현금)  일평균 승하차건수
# 1872      2075      11408

# %%
df.loc[df['승차건수(카드)'] == df['승차건수(카드)'].max() , ]
# Out:
#               정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  \
# 1872  롯데백화점(인천터미널)     37513.0     177804     164453    175729    164453
#
#       승차건수(현금)  일평균 승하차건수
# 1872      2075      11408

# %%
# 상관관계 분석을 위해서, pairplot 을 그려보자.

# %%
sb.pairplot(df)   
plt.show()
# Out:
# C:\Users\406\.conda\envs\st_311\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\406\.conda\envs\st_311\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 47448 (\N{HANGUL SYLLABLE RYU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\406\.conda\envs\st_311\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\406\.conda\envs\st_311\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\406\.conda\envs\st_311\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
# ...

# %%
df.corr(numeric_only=True)
# Out:
#             정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  승차건수(현금)  \
# 정류소아이디(ID)    1.000000  -0.125183  -0.131628 -0.124539 -0.131628 -0.143456
# 승차건수(총합계)    -0.125183   1.000000   0.787710  0.999962  0.787710  0.771904
# 하차건수(총합계)    -0.131628   0.787710   1.000000  0.787616  1.000000  0.612751
# 승차건수(카드)     -0.124539   0.999962   0.787616  1.000000  0.787616  0.766355
# 하차건수(카드)     -0.131628   0.787710   1.000000  0.787616  1.000000  0.612751
# 승차건수(현금)     -0.143456   0.771904   0.612751  0.766355  0.612751  1.000000
# 일평균 승하차건수    -0.135568   0.951836   0.938654  0.951768  0.938654  0.737078
#
#             일평균 승하차건수
# 정류소아이디(ID)  -0.135568
# 승차건수(총합계)    0.951836
# 하차건수(총합계)    0.938654
# 승차건수(카드)     0.951768
# 하차건수(카드)     0.938654
# 승차건수(현금)     0.737078
# 일평균 승하차건수    1.000000

# %%
# 예측 인공지능 개발

# %%
df.isna().sum()
# Out:
# 정류소명          0
# 정류소아이디(ID)    1
# 승차건수(총합계)     0
# 하차건수(총합계)     0
# 승차건수(카드)      0
# 하차건수(카드)      0
# 승차건수(현금)      0
# 일평균 승하차건수     0
# dtype: int64

# %%
df.head(3)
# Out:
#          정류소명  정류소아이디(ID)  승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  승차건수(현금)  \
# 0  (구)국제여객터미널     35051.0         99       1671        21      1671        78
# 1  (구)국제여객터미널     35052.0       2374         44      2312        44        62
# 2   (주)경동세라믹스     89146.0        315         39       312        39         3
#
#    일평균 승하차건수
# 0         59
# 1         80
# 2         11

# %%
y = df['일평균 승하차건수']

# %%
X = df.loc[ :  , '승차건수(총합계)' : '승차건수(현금)']

# %%
y
# Out:
# 0        59
# 1        80
# 2        11
# 3        59
# 4       163
#        ...
# 6415    208
# 6416    864
# 6417    840
# 6418    403
# 6419    236
# Name: 일평균 승하차건수, Length: 6420, dtype: int64

# %%
X
# Out:
#       승차건수(총합계)  하차건수(총합계)  승차건수(카드)  하차건수(카드)  승차건수(현금)
# 0            99       1671        21      1671        78
# 1          2374         44      2312        44        62
# 2           315         39       312        39         3
# 3           973        814       957       814        16
# 4          1452       3459      1424      3459        28
# ...         ...        ...       ...       ...       ...
# 6415       1781       4482      1749      4482        32
# 6416      10669      15269     10502     15269       167
# 6417      16539       8669     16195      8669       344
# 6418       5178       6917      5118      6917        60
# 6419       4027       3057      3975      3057        52
#
# [6420 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_test
# Out:
# 4141    125
# 3066      2
# 5053     42
# 6266    116
# 655       0
#        ...
# 3875    946
# 1676    177
# 2500    268
# 4789    112
# 6070    652
# Name: 일평균 승하차건수, Length: 1605, dtype: int64

# %%
mse = ((y_test - y_pred) ** 2).mean()

# %%
mse
# Out:
# 0.08343959360436999

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor2 = RandomForestRegressor()

# %%
regressor2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = regressor2.predict(X_test)

# %%
mse2 = ((y_test - y_pred2)**2).mean()

# %%
mse
# Out:
# 0.08343959360436999

# %%
mse2
# Out:
# 4205.686347850468

# %%
import os

# %%
os.makedirs('model')

# %%
import joblib

# %%
joblib.dump(regressor, './model/regressor.pkl')
# Out:
# ['./model/regressor.pkl']
